# %%
import pandas as pd

# Đường dẫn tới file (để tên file giống y hệt file bạn đã tải)
train_path = "train-00000-of-00001.parquet"
test_path = "test-00000-of-00001.parquet"

# Đọc file parquet vào Pandas DataFrame
df_train = pd.read_parquet(train_path)
df_test = pd.read_parquet(test_path)

# Trong Jupyter Notebook, dùng hàm display() sẽ hiển thị bảng dữ liệu đẹp và dễ nhìn hơn print()
display(df_train.head())

# In ra thông tin các cột và số lượng dữ liệu
print("\nThông tin tập Train:")
df_train.info()
# Out:
#                                                 text      source  s  len  \
# 0  deficit financing. Also found in: Dictionary, ...  refinedweb  5  506
# 1  Technical Director, Highways – Luton. An exper...  refinedweb  5  678
# 2  AMISH, DIY, Off Grid, Washing Machine.. How to...  refinedweb  5  647
# 3  Max Remerie. Programme Manager. HSD. The Nethe...  refinedweb  5  934
# 4  Description. Join us each Tuesday, during the ...  refinedweb  5  746
#
#       idx                                           textbook
# 0  204739  Lesson: Understanding Government Finance\n\nIn...
# 1   12487  **Lesson: Technical Director Roles and Respons...
# 2  477791  Lesson: DIY Off Grid Washing Machine\n\n### In...
# 3  448128  Lesson: Introduction to Cybersecurity\n\n## Se...
# 4  165515  Lesson: Introduction to Cubing\n## I. Theoreti...
# Thông tin tập Train:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 399000 entries, 0 to 398999
# Data columns (total 6 columns):
# ...
